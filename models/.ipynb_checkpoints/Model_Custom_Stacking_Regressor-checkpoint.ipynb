# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression
from prettytable import PrettyTable
from xgboost import XGBRegressor
# %matplotlib inline

# %%
_PickleFilesFolder="pickle_files"
_PickleFile_Merged_Listing_NY="Merged_Listing_NY"
_PickleFile_Vectorized_Data="NY_Vectors"
_FolderPath="data"
_Pretty_table_logs = PrettyTable()
_Pretty_table_logs.field_names = ["Model Name", "MAE", "MSE","RMSE","R2"]

# %%
def getDataFrameFromNParray(fileName):
    arr =np.load( "./" + _FolderPath + "/" + _PickleFile_Merged_Listing_NY + "_" + fileName)['arr_0']
    return(pd.DataFrame(arr))

# %%
def getTrainingData(typeOfModel,sampleSize=-1):
    if (typeOfModel=="corr"):
        trainFile= "c_X_train_Final_1.npz"
        testFile="c_X_test_Final_1.npz"
    elif (typeOfModel=="pca"):
        trainFile= "X_train_Final_2.npz"
        testFile="X_test_Final_2.npz"
        
    ytrainFile="c_y_train.npz"
    ytestFile="c_y_test.npz"
    
    X_train=getDataFrameFromNParray(trainFile)
    X_test=getDataFrameFromNParray(testFile)
    y_train=getDataFrameFromNParray(ytrainFile)
    y_test=getDataFrameFromNParray(ytestFile)
    if sampleSize >0 :
        X_train=X_train.head(sampleSize)
        X_test=X_test.head(sampleSize)
        y_train=y_train.head(sampleSize)
        y_test=y_test.head(sampleSize)
    return X_train,X_test,y_train,y_test

# %%
def trainModel(objModelType,X,y,gridSearhParams):
    # define evaluation
    cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
    # define search
    gsv = GridSearchCV(objModelType, gridSearhParams, scoring='r2', n_jobs=-1, cv=cv,verbose=2,return_train_score=True)
    # execute search
    result = gsv.fit(X, y)
   
    return result

# %%
ridge_alpha=[10,15,25,30,50,100,150,200,500,600,700,750,785,790,800,900,1000,1001]
def trainRidgeModel(X,y):
    model = Ridge()
    space = dict()
    #space['solver'] = ['svd', 'cholesky', 'lsqr', 'sag']
    space['alpha'] = ridge_alpha
    #space['fit_intercept'] = [True, False]
    #space['normalize'] = [True, False]
    return trainModel(model,X,y,space)

# %%
lasso_alpha=[0.0005,0.0006,0.06,0.5,0.0001,0.01,1,2,3,4,4.4,4]
def trainLassoModel(X,y):
    model = Lasso ()
    space = dict()
    #space['solver'] = ['svd', 'cholesky', 'lsqr', 'sag']
    space['alpha'] = lasso_alpha
    #space['fit_intercept'] = [True, False]
    #space['normalize'] = [True, False]
    return trainModel(model,X,y,space)

# %%
lasso_e=[0.0005,0.0006,0.06,0.5,0.0001,0.01,1]
def trainElasticNetModel(X,y):
    model = ElasticNet ()
    space = dict()
    #space['solver'] = ['svd', 'cholesky', 'lsqr', 'sag']
    space['alpha'] = lasso_e
    #space['fit_intercept'] = [True, False]
    #space['normalize'] = [True, False]
    return trainModel(model,X,y,space)

# %%
svr_c=[0.001, 0.01, 0.1, 1]
def trainSVR(X,y):
    parameters = {'kernel': ['rbf'], 'C':[0.001, 0.01, 0.1, 1],'gamma': [ 0.1, 0.01, 0.001 ],'epsilon':[0.1]}
    model = SVR(verbose=True)
    return trainModel(model,X,y,parameters)

# %%
def trainXGBRegressor(X,y):
    parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
    'objective':['reg:linear'],
    'learning_rate': [.03, 0.05, .07], #so called `eta` value
    'max_depth': [5, 6, 7],
    'min_child_weight': [4],
    'subsample': [0.7],
    'colsample_bytree': [0.7],
    'n_estimators': [500]}   
    model = XGBRegressor()
    return trainModel(model,X,y,parameters)

# %%
#https://stackoverflow.com/questions/37161563/how-to-graph-grid-scores-from-gridsearchcv
#Plot validation graph with all params
def plot_Gridsearch_results(grid):
    """
    Params: 
        grid: A trained GridSearchCV object.
    """
    ## Results from grid search
    results = grid.cv_results_
    means_test = results['mean_test_score']
    stds_test = results['std_test_score']
    means_train = results['mean_train_score']
    stds_train = results['std_train_score']

    ## Getting indexes of values per hyper-parameter
    masks=[]
    masks_names= list(grid.best_params_.keys())
    for p_k, p_v in grid.best_params_.items():
        masks.append(list(results['param_'+p_k].data==p_v))

    params=grid.param_grid

    ## Ploting results
    fig, ax = plt.subplots(1,len(params),sharex='none', sharey='all',figsize=(20,5))
    fig.suptitle('Score per parameter')
    fig.text(0.04, 0.5, 'MEAN SCORE', va='center', rotation='vertical')
    pram_preformace_in_best = {}
    for i, p in enumerate(masks_names):
        m = np.stack(masks[:i] + masks[i+1:])
        pram_preformace_in_best
        best_parms_mask = m.all(axis=0)
        best_index = np.where(best_parms_mask)[0]
        x = np.array(params[p])
        y_1 = np.array(means_test[best_index])
        e_1 = np.array(stds_test[best_index])
        y_2 = np.array(means_train[best_index])
        e_2 = np.array(stds_train[best_index])
        ax[i].errorbar(x, y_1, e_1, linestyle='--', marker='o', label='test')
        ax[i].errorbar(x, y_2, e_2, linestyle='-', marker='^',label='train' )
        ax[i].set_xlabel(p.upper())

    plt.legend()
    plt.show()

# %%
def plotValidationGraph(cs, clf, plt_title):
    #import math
    log_c =cs

   # for a in cs:
      #  b = math.log(a)
     #   log_c.append(b)

    plt.figure(figsize=(20,10))

    train_rmse = clf.cv_results_['mean_train_score']
    
    cv_rmse = clf.cv_results_['mean_test_score'] 
    
    plt.plot(log_c, train_rmse, label='Score Train')
    plt.plot(log_c, cv_rmse, label='Score CV')

    plt.scatter(log_c, train_rmse, label='Alphas Train')
    plt.scatter(log_c, cv_rmse, label='Alphas CV')

    plt.xlabel('Hyperparameter - Alpha')
    plt.ylabel('RMSE')
    plt.title("Score on various Alphas using %s on  "%plt_title)
    plt.grid(color='black', linestyle='-', linewidth=0.5)
    plt.legend()

# %%
def getPredictions(model,X_tr,y_tr,X_te,y_te,modelName=""):
    model.fit(X_tr,y_tr)
    predictions=model.predict(X_te)
    mae = metrics.mean_absolute_error(y_te, predictions)
    mse = metrics.mean_squared_error(y_te, predictions)
    rmse = np.sqrt(metrics.mean_squared_error(y_te, predictions))
    r2 = metrics.r2_score(y_te, predictions)

    #print('MAE (Mean Absolute Error): %s' %mae)
    #print('MSE (Mean Squared Error): %s' %mse)
    #print('RMSE (Root mean squared error): %s' %rmse)
    #print('R2 score: %s' %r2)
    if len(modelName) >0:
        _Pretty_table_logs.add_row([modelName, mae, mse,rmse,r2 ])
        pickle.dump(model, open(modelName, 'wb'))
        print (_Pretty_table_logs)
    return model,predictions

# %%
def getPredictionsGraph(y_te,predictions):
    # Evaluated predictions

    plt.figure(figsize=(15,7))
    plt.xlim(-10,350)
    sns.regplot(y=y_te, x=predictions, color='blue')
    plt.title('Evaluated predictions', fontsize=15)
    plt.xlabel('Predictions')
    plt.ylabel('Test')

# %% [markdown]
# # 1.   Regression Models With Removal  Corelated Features

# %%
X_train,X_test,y_train,y_test=getTrainingData("corr")

# %% [markdown]
# ##  1. 1 Ridge Regression

# %%
# %%time
clf=trainRidgeModel(X_train,y_train)
# Out:
# Fitting 30 folds for each of 18 candidates, totalling 540 fits
# CPU times: user 46.4 s, sys: 8.95 s, total: 55.4 s
# Wall time: 46min 55s

# %%
# %%time
plotValidationGraph(ridge_alpha,clf,'Ridge Model')
# Out:
# CPU times: user 45.2 ms, sys: 10.5 ms, total: 55.7 ms
# Wall time: 51.9 ms

# %%
# %%time
print('Best Alpha:', clf.best_estimator_.get_params()['alpha'])
print ('Best Score:',clf.best_score_)
bestAlpha= clf.best_estimator_.get_params()['alpha']
bestScore=clf.best_score_
# Out:
# Best Alpha: 30
# Best Score: 0.2982568342595708
# CPU times: user 2.34 ms, sys: 436 µs, total: 2.78 ms
# Wall time: 2.22 ms

# %%
model_r1,predictions_r1= getPredictions(Ridge(alpha=bestAlpha),X_train,y_train,X_test,y_test,"Ridge_1")
# Out:
# +------------+-------------------+--------------------+-------------------+---------------------+
# | Model Name |        MAE        |        MSE         |        RMSE       |          R2         |
# +------------+-------------------+--------------------+-------------------+---------------------+
# |  Ridge_1   | 74.56595620846423 | 36911.149467411546 | 192.1227458356026 | 0.33392504425907055 |
# +------------+-------------------+--------------------+-------------------+---------------------+

# %%
# Evaluated predictions
getPredictionsGraph(y_test,predictions_r1)

# %% [markdown]
# ## 1.2 Lasso Regression

# %%
# %%time
clf=trainLassoModel(X_train,y_train)
# Out:
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# CPU times: user 16.5 s, sys: 9.96 s, total: 26.5 s
# Wall time: 51min 9s

# %%
plotValidationGraph(lasso_alpha,clf,'Lasso Model')

# %%
print('Best Alpha:', clf.best_estimator_.get_params()['alpha'])
print ('Best Score:',clf.best_score_)
bestAlpha= clf.best_estimator_.get_params()['alpha']
bestScore=clf.best_score_
# Out:
# Best Alpha: 0.5
# Best Score: 0.29351881993889806

# %%
model_l1,predictions_l1= getPredictions(Lasso(alpha=bestAlpha),X_train,y_train,X_test,y_test,"Lasso")
# Out:
# +------------+-------------------+--------------------+--------------------+---------------------+
# | Model Name |        MAE        |        MSE         |        RMSE        |          R2         |
# +------------+-------------------+--------------------+--------------------+---------------------+
# |  Ridge_1   | 74.56595620846423 | 36911.149467411546 | 192.1227458356026  | 0.33392504425907055 |
# |   Lasso    | 73.07625445588782 | 37293.44588740743  | 193.11511045852274 | 0.32702636798637696 |
# +------------+-------------------+--------------------+--------------------+---------------------+

# %%
# Evaluated predictions
getPredictionsGraph(y_test,predictions_l1)

# %%
#https://www.kaggle.com/rodrigox93/graduate-admissions-lasso-gridsearchcv-0-0629
coefficients = pd.Series(model_l1.coef_, index = X_train.columns)

# %%
print("Lasso picked " + str(sum(coefficients != 0)) + " variables and eliminated the other " +  str(sum(coefficients == 0)) + " variables")
# Out:
# Lasso picked 58 variables and eliminated the other 5037 variables

# %%
imp_coef = pd.concat([coefficients.sort_values().head(7)])

plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
# Out:
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# # 1.3 Elastic Net Regression

# %%
# %%time
clf=trainElasticNetModel(X_train,y_train)
# Out:
# Fitting 30 folds for each of 7 candidates, totalling 210 fits
# CPU times: user 1min 13s, sys: 55.1 s, total: 2min 8s
# Wall time: 34min 39s

# %%
plotValidationGraph(lasso_e,clf,'Elastic Net Model')

# %%
print('Best Alpha:', clf.best_estimator_.get_params()['alpha'])
print ('Best Score:',clf.best_score_)
bestAlpha= clf.best_estimator_.get_params()['alpha']
bestScore=clf.best_score_
# Out:
# Best Alpha: 0.01
# Best Score: 0.29611369195369686

# %%
model_e1,predictions_e1= getPredictions(ElasticNet(alpha=bestAlpha),X_train,y_train,X_test,y_test,"Elastic net")
# Out:
# +-------------+-------------------+--------------------+--------------------+---------------------+
# |  Model Name |        MAE        |        MSE         |        RMSE        |          R2         |
# +-------------+-------------------+--------------------+--------------------+---------------------+
# |   Ridge_1   | 74.56595620846423 | 36911.149467411546 | 192.1227458356026  | 0.33392504425907055 |
# |    Lasso    | 73.07625445588782 | 37293.44588740743  | 193.11511045852274 | 0.32702636798637696 |
# | Elastic net | 73.26432087780388 | 37105.925090896766 | 192.62898299813756 |  0.330410248142876  |
# +-------------+-------------------+--------------------+--------------------+---------------------+

# %%
# Evaluated predictions
getPredictionsGraph(y_test,predictions_e1)

# %%
coefficients = pd.Series(model_e1.coef_, index = X_train.columns)

# %%
print("Elastic Net picked " + str(sum(coefficients != 0)) + " variables and eliminated the other " +  str(sum(coefficients == 0)) + " variables")
# Out:
# Elastic Net picked 3648 variables and eliminated the other 1447 variables

# %%
imp_coef = pd.concat([coefficients.sort_values().head(7)])

plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Elastic net Model")
# Out:
# Text(0.5, 1.0, 'Coefficients in the Elastic net Model')

# %% [markdown]
# # 2. Regression Models After PCA

# %%
X_train,X_test,y_train,y_test=getTrainingData("pca")

# %% [markdown]
# # 2. 1 Ridge Regression

# %%
# %%time
clf=trainRidgeModel(X_train,y_train)
# Out:
# Fitting 30 folds for each of 18 candidates, totalling 540 fits
# CPU times: user 14.3 s, sys: 3.4 s, total: 17.7 s
# Wall time: 12min 4s

# %%
# %%time
plotValidationGraph(ridge_alpha,clf,'Ridge Model')
# Out:
# CPU times: user 103 ms, sys: 273 ms, total: 377 ms
# Wall time: 48 ms

# %%
# %%time
print('Best Alpha:', clf.best_estimator_.get_params()['alpha'])
print ('Best Score:',clf.best_score_)
bestAlpha= clf.best_estimator_.get_params()['alpha']
bestScore=clf.best_score_
# Out:
# Best Alpha: 1001
# Best Score: 0.8124532801118377
# CPU times: user 1.03 ms, sys: 305 µs, total: 1.34 ms
# Wall time: 1.35 ms

# %%
model_r2,predictions_r2= getPredictions(Ridge(alpha=bestAlpha),X_train,y_train,X_test,y_test,"Ridge_2")
# Out:
# +------------+-----------------+-------------------+-------------------+--------------------+
# | Model Name |       MAE       |        MSE        |        RMSE       |         R2         |
# +------------+-----------------+-------------------+-------------------+--------------------+
# |  Ridge_2   | 36.518674302838 | 4855.960454092144 | 69.68472181254758 | 0.9123724486717821 |
# +------------+-----------------+-------------------+-------------------+--------------------+

# %%
# Evaluated predictions
getPredictionsGraph(y_test,predictions_r2)

# %% [markdown]
# # 2.1 Lasso Regression

# %%
# %%time
clf=trainLassoModel(X_train,y_train)

# %%
plotValidationGraph(lasso_alpha,clf,'Lasso Model')

# %%
print('Best Alpha:', clf.best_estimator_.get_params()['alpha'])
print ('Best Score:',clf.best_score_)
bestAlpha= clf.best_estimator_.get_params()['alpha']
bestScore=clf.best_score_
# Out:
# Best Alpha: 0.06
# Best Score: 0.8121980426230937

# %%
model_l2,predictions_l2= getPredictions(Lasso(alpha=bestAlpha),X_train,y_train,X_test,y_test,"Lasso_2")
# Out:
# +------------+-------------------+-------------------+-------------------+--------------------+
# | Model Name |        MAE        |        MSE        |        RMSE       |         R2         |
# +------------+-------------------+-------------------+-------------------+--------------------+
# |  Ridge_2   |  36.518674302838  | 4855.960454092144 | 69.68472181254758 | 0.9123724486717821 |
# |  Lasso_2   | 36.35021638739281 | 4842.999175459576 | 69.59166024359223 | 0.9126063396021947 |
# +------------+-------------------+-------------------+-------------------+--------------------+

# %%
# Evaluated predictions
getPredictionsGraph(y_test,predictions_l2)

# %%
#https://www.kaggle.com/rodrigox93/graduate-admissions-lasso-gridsearchcv-0-0629
coefficients = pd.Series(model_l2.coef_, index = X_train.columns)
print("Lasso picked " + str(sum(coefficients != 0)) + " variables and eliminated the other " +  str(sum(coefficients == 0)) + " variables")
# Out:
# Lasso picked 2403 variables and eliminated the other 97 variables

# %%
imp_coef = pd.concat([coefficients.sort_values().head(10)])

plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
# Out:
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# # 2.3 Elastic Net Regression

# %%
# %%time
clf=trainElasticNetModel(X_train,y_train)
# Out:
# Fitting 30 folds for each of 7 candidates, totalling 210 fits
# CPU times: user 2.04 s, sys: 923 ms, total: 2.96 s
# Wall time: 52.3 s

# %%
plotValidationGraph(lasso_e,clf,'Elastic Net Model')

# %%
print('Best Alpha:', clf.best_estimator_.get_params()['alpha'])
print ('Best Score:',clf.best_score_)
bestAlpha= clf.best_estimator_.get_params()['alpha']
bestScore=clf.best_score_
# Out:
# Best Alpha: 0.5
# Best Score: 0.813183246064207

# %%
model_e2,predictions_e2= getPredictions(ElasticNet(alpha=bestAlpha),X_train,y_train,X_test,y_test,"Elastic net")
# Out:
# +-------------+--------------------+-------------------+-------------------+--------------------+
# |  Model Name |        MAE         |        MSE        |        RMSE       |         R2         |
# +-------------+--------------------+-------------------+-------------------+--------------------+
# |   Ridge_2   |  36.518674302838   | 4855.960454092144 | 69.68472181254758 | 0.9123724486717821 |
# |   Lasso_2   | 36.35021638739281  | 4842.999175459576 | 69.59166024359223 | 0.9126063396021947 |
# | Elastic net | 30.846923526395752 | 4043.212727618164 | 63.58626209817781 | 0.927038773447651  |
# +-------------+--------------------+-------------------+-------------------+--------------------+

# %%
# Evaluated predictions
getPredictionsGraph(y_test,predictions_e2)

# %% [markdown]
# # 2.4 Support Vector Regressor

# %%
X_train,X_test,y_train,y_test=getTrainingData("pca",10000)

# %%
# %%time
clf=trainSVR(X_train,y_train)
# Out:
# Fitting 30 folds for each of 12 candidates, totalling 360 fits

# %%
clf.best_score_
# Out:
# -0.040715435177182555

# %%
plot_Gridsearch_results(clf)

# %%
print('Best Params:', clf.best_estimator_.get_params())
print ('Best Score:',clf.best_score_)
# Out:
# Best Params: {'C': 1, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 0.001, 'kernel': 'rbf', 'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': True}
# Best Score: -0.040715435177182555

# %%
best_c=clf.best_estimator_.get_params()["C"]
ep=clf.best_estimator_.get_params()["epsilon"]
ker=clf.best_estimator_.get_params()["kernel"]

# %%
 # %%time
model_svr1,predictions_svr1= getPredictions(SVR(kernel=ker,C=best_c,epsilon=ep ),X_train,y_train,X_test,y_test,"SVR1")
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# +------------+-------------------+-------------------+--------------------+----------------------+
# | Model Name |        MAE        |        MSE        |        RMSE        |          R2          |
# +------------+-------------------+-------------------+--------------------+----------------------+
# |    XGB     | 25.78214154948592 |  5501.69558696085 | 74.17341563498913  |  0.9027661775498415  |
# |    XGB     | 25.78214154948592 |  5501.69558696085 | 74.17341563498913  |  0.9027661775498415  |
# |    SVR1    | 77.80728856308123 | 56477.94560632705 | 237.65089018627103 | 0.001841078148624442 |
# +------------+-------------------+-------------------+--------------------+----------------------+
# ...

# %%
getPredictionsGraph(y_test,predictions_svr1)

# %% [markdown]
# # 2.5 XGB Regressor

# %%
X_train,X_test,y_train,y_test=getTrainingData("pca",10000)

# %%
# %%time
clf=trainXGBRegressor(X_train,y_train)
# Out:
# Fitting 30 folds for each of 9 candidates, totalling 270 fits

# %%
clf.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=7,
#              min_child_weight=4, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=4, nthread=4, num_parallel_tree=1,
#              objective='reg:linear', random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=0.7, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
plot_Gridsearch_results(clf)

# %%
# %%time

model_xgb1,predictions_xgb1= getPredictions(XGBRegressor(**clf.best_params_),X_train,y_train,X_test,y_test,"XGB")
# Out:
# [06:50:29] WARNING: ../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# +------------+-------------------+------------------+-------------------+--------------------+
# | Model Name |        MAE        |       MSE        |        RMSE       |         R2         |
# +------------+-------------------+------------------+-------------------+--------------------+
# |    XGB     | 25.78214154948592 | 5501.69558696085 | 74.17341563498913 | 0.9027661775498415 |
# |    XGB     | 25.78214154948592 | 5501.69558696085 | 74.17341563498913 | 0.9027661775498415 |
# +------------+-------------------+------------------+-------------------+--------------------+
# CPU times: user 24min 8s, sys: 431 ms, total: 24min 8s
# Wall time: 6min 2s

# %%
getPredictionsGraph(y_test,predictions_xgb1)

# %%
feature_important = model_xgb1.get_booster().get_score(importance_type='weight')

# %%
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)

# %%
data.head(20).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2.6 SVR with All Records  and Trainable params with 10k records

# %%
X_train,X_test,y_train,y_test=getTrainingData("pca")

# %%
 # %%time
model_svr2,predictions_svr2= getPredictions(SVR(kernel=ker,C=best_c,epsilon=ep ),X_train,y_train,X_test,y_test,"SVR2")
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# +------------+-------------------+-------------------+--------------------+----------------------+
# | Model Name |        MAE        |        MSE        |        RMSE        |          R2          |
# +------------+-------------------+-------------------+--------------------+----------------------+
# |    XGB     | 25.78214154948592 |  5501.69558696085 | 74.17341563498913  |  0.9027661775498415  |
# |    XGB     | 25.78214154948592 |  5501.69558696085 | 74.17341563498913  |  0.9027661775498415  |
# |    SVR1    | 77.80728856308123 | 56477.94560632705 | 237.65089018627103 | 0.001841078148624442 |
# |    SVR2    | 69.96955801729052 | 52134.32653035644 | 228.3294254588235  | 0.059217343882801976 |
# ...

# %% [markdown]
# # 2.7 XGB with All Records  and Trainable params with 10k records

# %%
xgb2=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.7, gamma=0, 
             importance_type='gain', interaction_constraints='',
             learning_rate=0.05, max_delta_step=0, max_depth=7,
             min_child_weight=4,
             n_estimators=500, n_jobs=-1, 
             objective='reg:squarederror', random_state=0, reg_alpha=0, reg_lambda=1,
             scale_pos_weight=1, subsample=0.7, tree_method='exact',
             validate_parameters=1, verbosity=None)

# %%
# %%time

model_xgb2,predictions_xgb2= getPredictions(xgb2,X_train,y_train,X_test,y_test,"XGB")
# Out:
# +------------+--------------------+-------------------+--------------------+----------------------+
# | Model Name |        MAE         |        MSE        |        RMSE        |          R2          |
# +------------+--------------------+-------------------+--------------------+----------------------+
# |    XGB     | 25.78214154948592  |  5501.69558696085 | 74.17341563498913  |  0.9027661775498415  |
# |    XGB     | 25.78214154948592  |  5501.69558696085 | 74.17341563498913  |  0.9027661775498415  |
# |    SVR1    | 77.80728856308123  | 56477.94560632705 | 237.65089018627103 | 0.001841078148624442 |
# |    SVR2    | 69.96955801729052  | 52134.32653035644 | 228.3294254588235  | 0.059217343882801976 |
# |    XGB     | 24.740368737717848 | 4261.062659391621 | 65.27681563458516  |  0.9231075931469052  |
# +------------+--------------------+-------------------+--------------------+----------------------+
# CPU times: user 1h 53min 41s, sys: 1.1 s, total: 1h 53min 42s
# ...

# %% [markdown]
# # Final Summary

# %% [markdown]
# <!-- #######  THIS IS A COMMENT - Visible only in the source editor #########-->
# <table class="editorDemoTable" style="width: 737px; height: 150px;">
# <tbody>
# <tr>
# <td style="width: 80.8333px;"><strong>S.No.</strong></td>
# <td style="width: 185.167px;"><strong>Model Name</strong></td>
# <td style="width: 116px;"><strong>Hyper Param Tuning Records</strong></td>
# <td style="width: 61px;"><strong>Training Records</strong></td>
# <td style="width: 64px;"><strong>With PCA</strong></td>
# <td style="width: 60px;"><strong>MAE</strong></td>
# <td style="width: 50px;"><strong>MSE</strong></td>
# <td style="width: 89px;"><strong>RMSE</strong></td>
# <td style="width: 89px;"><strong>R-Square</strong></td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">1.</td>
# <td style="width: 185.167px;">Ridge</td>
# <td style="width: 116px;">25k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">No</td>
# <td style="width: 60px;">74.56</td>
# <td style="width: 50px;">36911.14</td>
# <td style="width: 89px;">&nbsp;192.12</td>
# <td style="width: 89px;">&nbsp;0.3339</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">2.</td>
# <td style="width: 185.167px;">Lasso</td>
# <td style="width: 116px;">25k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">No</td>
# <td style="width: 60px;">73.07</td>
# <td style="width: 50px;">37293.44</td>
# <td style="width: 89px;">&nbsp;193.11</td>
# <td style="width: 89px;">&nbsp;0.3270</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">3.</td>
# <td style="width: 185.167px;">Elastic Net</td>
# <td style="width: 116px;">25k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">No</td>
# <td style="width: 60px;">73.26</td>
# <td style="width: 50px;">37105.92</td>
# <td style="width: 89px;">&nbsp;192.62</td>
# <td style="width: 89px;">&nbsp;0.33041</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">4.</td>
# <td style="width: 185.167px;">Ridge</td>
# <td style="width: 116px;">25k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">36.51&nbsp;</td>
# <td style="width: 50px;">4855.96&nbsp;</td>
# <td style="width: 89px;">&nbsp;69.68</td>
# <td style="width: 89px;">&nbsp;0.9123</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">5.</td>
# <td style="width: 185.167px;">Lasso</td>
# <td style="width: 116px;">25k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">36.35</td>
# <td style="width: 50px;">4842.99&nbsp;</td>
# <td style="width: 89px;">&nbsp;69.59</td>
# <td style="width: 89px;">&nbsp;0.9126</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">6.</td>
# <td style="width: 185.167px;">Ealstic Net</td>
# <td style="width: 116px;">25k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">30.84</td>
# <td style="width: 50px;">4043.21</td>
# <td style="width: 89px;">&nbsp;63.58</td>
# <td style="width: 89px;">&nbsp;0.9270</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">7.</td>
# <td style="width: 185.167px;">SVR</td>
# <td style="width: 116px;">10k</td>
# <td style="width: 61px;">10k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">77.80&nbsp;</td>
# <td style="width: 50px;">56477.94</td>
# <td style="width: 89px;">&nbsp;237.65</td>
# <td style="width: 89px;">&nbsp;0.0018</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">8.</td>
# <td style="width: 185.167px;">XGB</td>
# <td style="width: 116px;">10k</td>
# <td style="width: 61px;">10k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">25.78&nbsp;</td>
# <td style="width: 50px;">5501.69&nbsp;</td>
# <td style="width: 89px;">74.17</td>
# <td style="width: 89px;">0.90</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">9.</td>
# <td style="width: 185.167px;">SVR</td>
# <td style="width: 116px;">10k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">69.96&nbsp;</td>
# <td style="width: 50px;">52134.32</td>
# <td style="width: 89px;">228.32</td>
# <td style="width: 89px;">0.059</td>
# </tr>
# <tr>
# <td style="width: 80.8333px;">10.</td>
# <td style="width: 185.167px;">XGB</td>
# <td style="width: 116px;">10k</td>
# <td style="width: 61px;">25k</td>
# <td style="width: 64px;">Yes</td>
# <td style="width: 60px;">24.74</td>
# <td style="width: 50px;">4261.06</td>
# <td style="width: 89px;">65.27</td>
# <td style="width: 89px;">0.9231</td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>

# %% [markdown]
# # Custom Stacking Regressor

# %%
'''
1) Split whole data into train and test(80-20)

2) Now, in the 80% train set, split the train set into D1 and D2.(50-50).

From this D1, do sampling with replacement to create d1,d2,d3....dk(k samples).

Now create 'k' models and train each of these models with each of these k samples.

3) Now pass the D2 set to each of these k models; now, you will get k predictions for D2 from each of these models.

4) Now, using these k predictions, create a new dataset, and for D2, you already know it's corresponding target values, so now you train a metamodel with these k predictions.

5) Now, for model evaluation, you have can use the 20% data that you have kept as the test set. Pass that test set to each of the base models, and you will get 'k' predictions. Now you create a new dataset with these k predictions and pass it to your metamodel, and you will get the final prediction. Using this final prediction and the targets for the test set, you can calculate the model's performance score.

I hope you got it. For base models, you can consider any combination of models; you can take the DecisionTreeRegressor, LinearRegression, Lasso, Ridge, SVR, XGBoost, etc. And here, you can tune for the number of base models. The procedure mentioned above requires you to do custom coding. There are no library functions available for this as it is a custom model implementation.
'''

# %%
X_train,X_test,y_train,y_test=getTrainingData("pca")

# %%
print("X Train", X_train.shape)
print("X Test", X_test.shape)
print("Y Train", y_train.shape)
print("Y Test", y_test.shape)
# Out:
# X Train (25830, 2500)
# X Test (11070, 2500)
# Y Train (25830, 1)
# Y Test (11070, 1)

# %%
total_records= X_train.shape[0]
split_ratio= int(total_records/2)
d1= X_train.head(split_ratio)
d2=X_train.tail(split_ratio)

# %%
print("d1 : ",d1.shape)
print("d2 : " ,d2.shape)
# Out:
# d1 :  (12915, 2500)
# d2 :  (12915, 2500)

# %%
d1.head(2)
# Out:
#        0         1         2         3         4         5         6     \
# 0 -0.586542 -1.631930 -0.019916 -0.089462  0.044594 -0.425410 -0.045469
# 1 -0.409313 -1.126919 -0.336763  0.005500 -0.566961 -0.345098 -0.063892
#
#        7         8         9     ...      2490      2491      2492      2493  \
# 0 -0.110874 -2.120859 -0.031917  ...  0.639620 -0.656748  0.963646 -1.022086
# 1 -0.103199  0.452194 -0.533118  ...  0.162773  0.152399 -0.215847  0.031306
#
#        2494      2495      2496      2497      2498      2499
# 0 -0.877638  0.702638 -0.089110 -1.207414  0.639238 -0.007395
# 1  0.879390  0.766199 -0.750508 -0.704695 -0.023904 -0.741890
#
# [2 rows x 2500 columns]

# %%
d1.tail(2)
# Out:
#            0           1         2          3         4          5     \
# 12913 -0.597278  116.672402  1.203713 -21.753679  0.433088 -15.841844
# 12914 -0.463731   -0.546590 -0.603854   0.039073 -1.228473  -0.617646
#
#              6         7         8         9     ...      2490      2491  \
# 12913  109.281658  0.021638 -0.623893 -0.539662  ...  0.068772 -0.399336
# 12914   -0.054227 -0.494768  2.933023 -0.667818  ...  1.296661 -1.856179
#
#            2492      2493      2494      2495      2496      2497      2498  \
# 12913  0.133392 -0.163144  0.257586  0.430888 -0.103900  0.439046  0.012334
# 12914  0.053620 -0.710168 -1.605186 -0.034967 -0.321875 -2.387310  0.889337
#
#            2499
# 12913 -0.340637
# 12914 -0.016735
#
# [2 rows x 2500 columns]

# %%
d2.head(2)
# Out:
#            0         1         2         3         4         5         6     \
# 12915  3.130539 -1.488276 -0.298397 -0.016923 -0.809246 -0.508264  0.007355
# 12916 -0.517328 -0.823789 -0.345555  0.052451 -0.252805 -0.386052 -0.069594
#
#            7         8         9     ...      2490      2491      2492  \
# 12915 -0.439340 -0.051884 -0.157086  ...  0.642510 -1.431326  1.065175
# 12916 -0.220291 -2.296210  0.387650  ... -1.301314 -0.791381 -0.836329
#
#            2493      2494      2495      2496      2497      2498      2499
# 12915  0.624341 -0.151847 -0.834710  0.246901  1.102957 -0.279443  0.150567
# 12916 -1.891264  0.330035  1.512521  0.892637 -0.479211  0.590247 -0.010474
#
# [2 rows x 2500 columns]

# %%
d2.tail(2)
# Out:
#            0         1         2         3         4         5         6     \
# 25828 -0.456833 -1.363368 -0.450239 -0.015568 -0.841152 -0.442661 -0.077494
# 25829 -0.418889 -0.933990 -0.260542 -0.042450 -0.062761 -0.307976 -0.051270
#
#            7         8         9     ...      2490      2491      2492  \
# 25828 -0.390219  0.522980 -0.739415  ...  1.000094 -0.990729  0.901009
# 25829  0.286619 -1.534001 -0.803330  ...  0.315605 -0.078603  0.309370
#
#            2493      2494      2495      2496      2497     2498      2499
# 25828 -0.738900  0.230518  1.277600  1.540928 -0.421378  0.06813  1.006868
# 25829 -0.258389  0.764571 -0.297243 -0.589327 -0.627818 -1.35695  0.104027
#
# [2 rows x 2500 columns]
